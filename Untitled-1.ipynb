# %%
primera_velocidad=int
segunda_velocidad=int
tercera_velocidad=int
cuarta_velocidad=int
quinta_velocidad=int
velocidad=int(input("ingrese su velocidad"))
print()

# %%
compras=[["jose",30000,18000,40000]
         ["maria",20000,15000,50000],
         ["miguel",15000,89000,870000],
 ]
for i in compras:
      compras=-30.000
